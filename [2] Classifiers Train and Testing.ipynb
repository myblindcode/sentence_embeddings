# %%
import json

EMBEDDINGS_PATH = './EMBEDDINGS/'

embeddings_meta = []

with open(f'{EMBEDDINGS_PATH}embeddings_meta.jsonl', 'r', encoding="utf-8") as f:
    for l in f:
        embeddings_meta.append(json.loads(l))

# %%
import json
import os

already_processed = set()

if os.path.exists('results.jsonl'):
    with open('results.jsonl', 'r', encoding="utf-8") as f:
        for l in f:
            item = json.loads(l)
            already_processed.add((item['dataset'], item['lm_model'], item['cls_model']))

# %%
already_processed
# Out:
# {('CSAbstruct', 'all-MiniLM-L6-v2', 'DecisionTreeClassifier'),
#  ('CSAbstruct', 'all-MiniLM-L6-v2', 'KNeighborsClassifierSqrt'),
#  ('CSAbstruct', 'all-MiniLM-L6-v2', 'MLPClassifier'),
#  ('CSAbstruct', 'all-MiniLM-L6-v2', 'RandomForestClassifier'),
#  ('CSAbstruct', 'all-MiniLM-L6-v2', 'SVM'),
#  ('CSAbstruct', 'scibert_scivocab_uncased', 'DecisionTreeClassifier'),
#  ('CSAbstruct', 'scibert_scivocab_uncased', 'KNeighborsClassifierSqrt'),
#  ('CSAbstruct', 'scibert_scivocab_uncased', 'MLPClassifier'),
#  ('CSAbstruct', 'scibert_scivocab_uncased', 'RandomForestClassifier'),
#  ('CSAbstruct', 'scibert_scivocab_uncased', 'SVM'),
#  ('CSAbstruct', 'st_minilm_abstruct', 'DecisionTreeClassifier'),
#  ('CSAbstruct', 'st_minilm_abstruct', 'KNeighborsClassifierSqrt'),
#  ('CSAbstruct', 'st_minilm_abstruct', 'MLPClassifier'),
#  ('CSAbstruct', 'st_minilm_abstruct', 'RandomForestClassifier'),
#  ('CSAbstruct', 'st_minilm_abstruct', 'SVM'),
#  ('CSAbstruct', 'st_scibert_abstruct', 'DecisionTreeClassifier'),
#  ('CSAbstruct', 'st_scibert_abstruct', 'KNeighborsClassifierSqrt'),
#  ('CSAbstruct', 'st_scibert_abstruct', 'MLPClassifier'),
#  ('CSAbstruct', 'st_scibert_abstruct', 'RandomForestClassifier'),
#  ('CSAbstruct', 'st_scibert_abstruct', 'SVM'),
#  ('PMC-Sents-FULL', 'all-MiniLM-L6-v2', 'DecisionTreeClassifier'),
#  ('PMC-Sents-FULL', 'all-MiniLM-L6-v2', 'KNeighborsClassifierSqrt'),
#  ('PMC-Sents-FULL', 'all-MiniLM-L6-v2', 'MLPClassifier'),
#  ('PMC-Sents-FULL', 'all-MiniLM-L6-v2', 'RandomForestClassifier'),
#  ('PMC-Sents-FULL', 'all-MiniLM-L6-v2', 'SVM'),
#  ('PMC-Sents-FULL', 'scibert_scivocab_uncased', 'DecisionTreeClassifier'),
#  ('PMC-Sents-FULL', 'scibert_scivocab_uncased', 'KNeighborsClassifierSqrt'),
#  ('PMC-Sents-FULL', 'scibert_scivocab_uncased', 'MLPClassifier'),
#  ('PMC-Sents-FULL', 'scibert_scivocab_uncased', 'RandomForestClassifier'),
#  ('PMC-Sents-FULL', 'scibert_scivocab_uncased', 'SVM'),
#  ('PMC-Sents-FULL', 'st_minilm_pmc_sents_full', 'DecisionTreeClassifier'),
#  ('PMC-Sents-FULL', 'st_minilm_pmc_sents_full', 'KNeighborsClassifierSqrt'),
#  ('PMC-Sents-FULL', 'st_minilm_pmc_sents_full', 'MLPClassifier'),
#  ('PMC-Sents-FULL', 'st_minilm_pmc_sents_full', 'RandomForestClassifier'),
#  ('PMC-Sents-FULL', 'st_minilm_pmc_sents_full', 'SVM'),
#  ('PMC-Sents-FULL', 'st_scibert_pmc_sents_full', 'DecisionTreeClassifier'),
#  ('PMC-Sents-FULL', 'st_scibert_pmc_sents_full', 'KNeighborsClassifierSqrt'),
#  ('PMC-Sents-FULL', 'st_scibert_pmc_sents_full', 'MLPClassifier'),
#  ('PMC-Sents-FULL', 'st_scibert_pmc_sents_full', 'RandomForestClassifier'),
#  ('PMC-Sents-FULL', 'st_scibert_pmc_sents_full', 'SVM'),
#  ('PubMed-RCT', 'all-MiniLM-L6-v2', 'DecisionTreeClassifier'),
#  ('PubMed-RCT', 'all-MiniLM-L6-v2', 'KNeighborsClassifierSqrt'),
#  ('PubMed-RCT', 'all-MiniLM-L6-v2', 'MLPClassifier'),
#  ('PubMed-RCT', 'all-MiniLM-L6-v2', 'RandomForestClassifier'),
#  ('PubMed-RCT', 'all-MiniLM-L6-v2', 'SVM'),
#  ('PubMed-RCT', 'scibert_scivocab_uncased', 'DecisionTreeClassifier'),
#  ('PubMed-RCT', 'scibert_scivocab_uncased', 'KNeighborsClassifierSqrt'),
#  ('PubMed-RCT', 'scibert_scivocab_uncased', 'MLPClassifier'),
#  ('PubMed-RCT', 'scibert_scivocab_uncased', 'RandomForestClassifier'),
#  ('PubMed-RCT', 'scibert_scivocab_uncased', 'SVM'),
#  ('PubMed-RCT', 'st_minilm_pubmed_rct', 'DecisionTreeClassifier'),
#  ('PubMed-RCT', 'st_minilm_pubmed_rct', 'KNeighborsClassifierSqrt'),
#  ('PubMed-RCT', 'st_minilm_pubmed_rct', 'MLPClassifier'),
#  ('PubMed-RCT', 'st_minilm_pubmed_rct', 'RandomForestClassifier'),
#  ('PubMed-RCT', 'st_minilm_pubmed_rct', 'SVM'),
#  ('PubMed-RCT', 'st_scibert_pubmed_rct', 'DecisionTreeClassifier'),
#  ('PubMed-RCT', 'st_scibert_pubmed_rct', 'KNeighborsClassifierSqrt'),
#  ('PubMed-RCT', 'st_scibert_pubmed_rct', 'MLPClassifier'),
#  ('PubMed-RCT', 'st_scibert_pubmed_rct', 'RandomForestClassifier'),
#  ('PubMed-RCT', 'st_scibert_pubmed_rct', 'SVM')}

# %%
import numpy as np

seed = 31415
np.random.seed(seed)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import f1_score
import time

def cls_train_evaluate(clf,
                       embeddings_train,
                       embeddings_test,
                       y_train_true,
                       y_test_true):
    
    output_dict = {}
    
    start = time.time()
    clf = clf.fit(embeddings_train, y_train_true)
    end = time.time()
    y_pred = clf.predict(embeddings_test)

    output_dict['acc'] = accuracy_score(y_test_true, y_pred)
    output_dict['f1_macro'] = f1_score(y_test_true, y_pred, average='macro')
    output_dict['f1_micro'] = f1_score(y_test_true, y_pred, average='micro')
    output_dict['f1_weighted'] = f1_score(y_test_true, y_pred, average='weighted')
    output_dict['time'] = end - start
    
    return output_dict

# %%
import pickle
from tqdm.auto import tqdm
import math

cls_results = []
pbar_embeddings_meta = tqdm(embeddings_meta) 

for embedding_meta in pbar_embeddings_meta:
    pbar_embeddings_meta.set_description(embedding_meta['dataset_desc'] + "-" + embedding_meta['model_name'])
    
    with open(f"{EMBEDDINGS_PATH}{embedding_meta['file_name']}", 'rb') as f:
        embeddings = pickle.load(f)
    
    embeddings_train = embeddings['embeddings_train']
    embeddings_test = embeddings['embeddings_test']
    y_train_true = embeddings['y_train_true']
    y_test_true = embeddings['y_test_true']
    
    total_n_neighbors = math.ceil(math.sqrt(len(y_train_true)))
    
    cls_models = [
        ('DecisionTreeClassifier', tree.DecisionTreeClassifier(random_state=seed)),
        ('KNeighborsClassifierSqrt', KNeighborsClassifier(n_neighbors=total_n_neighbors, weights='distance')),
        ('RandomForestClassifier', RandomForestClassifier(random_state=seed)),
        ('MLPClassifier', MLPClassifier(random_state=seed)),
        ('SVM', SVC(random_state=seed)),
    ]
    
    cls_models_bar = tqdm(cls_models, leave=False)
    
    for cls_model in cls_models_bar:
        cls_models_bar.set_description(cls_model[0])
        
        item = (embedding_meta['dataset_desc'], embedding_meta['model_name'], cls_model[0])
        if item in already_processed:
            continue        
        
        clf = cls_model[1]
        
        output_dict = {
          'dataset': embedding_meta['dataset_desc'],
          'lm_model': embedding_meta['model_name'],
          'cls_model': cls_model[0],
        }        

        cls_result = cls_train_evaluate(clf,
                                        embeddings_train,
                                        embeddings_test,
                                        y_train_true,
                                        y_test_true)
        
        with open('results.jsonl', 'a', encoding="utf-8") as f:
            f.write(json.dumps({**output_dict, **cls_result}))
            f.write("\n")
        
        cls_results.append({**output_dict, **cls_result})
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import pandas as pd

pd.DataFrame(cls_results)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import json

cls_results = []

with open('results.jsonl', 'r', encoding="utf-8") as f:
    for l in f:
        item = json.loads(l)
        cls_results.append(item)

# %%
import pandas as pd

df_result = pd.DataFrame(cls_results)[['dataset', 'lm_model', 'cls_model', 'f1_micro']]
df_result['f1_micro'] = round(df_result['f1_micro'] * 100, 2)
df_result.sort_values(by=["dataset", "lm_model", "cls_model"])
# Out:
#            dataset                   lm_model                 cls_model  \
# 10      CSAbstruct           all-MiniLM-L6-v2    DecisionTreeClassifier
# 11      CSAbstruct           all-MiniLM-L6-v2  KNeighborsClassifierSqrt
# 13      CSAbstruct           all-MiniLM-L6-v2             MLPClassifier
# 12      CSAbstruct           all-MiniLM-L6-v2    RandomForestClassifier
# 14      CSAbstruct           all-MiniLM-L6-v2                       SVM
# 15      CSAbstruct   scibert_scivocab_uncased    DecisionTreeClassifier
# 16      CSAbstruct   scibert_scivocab_uncased  KNeighborsClassifierSqrt
# 18      CSAbstruct   scibert_scivocab_uncased             MLPClassifier
# 17      CSAbstruct   scibert_scivocab_uncased    RandomForestClassifier
# 19      CSAbstruct   scibert_scivocab_uncased                       SVM
# 0       CSAbstruct         st_minilm_abstruct    DecisionTreeClassifier
# 1       CSAbstruct         st_minilm_abstruct  KNeighborsClassifierSqrt
# 3       CSAbstruct         st_minilm_abstruct             MLPClassifier
# 2       CSAbstruct         st_minilm_abstruct    RandomForestClassifier
# 4       CSAbstruct         st_minilm_abstruct                       SVM
# 5       CSAbstruct        st_scibert_abstruct    DecisionTreeClassifier
# 6       CSAbstruct        st_scibert_abstruct  KNeighborsClassifierSqrt
# 8       CSAbstruct        st_scibert_abstruct             MLPClassifier
# 7       CSAbstruct        st_scibert_abstruct    RandomForestClassifier
# 9       CSAbstruct        st_scibert_abstruct                       SVM
# 50  PMC-Sents-FULL           all-MiniLM-L6-v2    DecisionTreeClassifier
# 51  PMC-Sents-FULL           all-MiniLM-L6-v2  KNeighborsClassifierSqrt
# 53  PMC-Sents-FULL           all-MiniLM-L6-v2             MLPClassifier
# 52  PMC-Sents-FULL           all-MiniLM-L6-v2    RandomForestClassifier
# 54  PMC-Sents-FULL           all-MiniLM-L6-v2                       SVM
# 55  PMC-Sents-FULL   scibert_scivocab_uncased    DecisionTreeClassifier
# 56  PMC-Sents-FULL   scibert_scivocab_uncased  KNeighborsClassifierSqrt
# 58  PMC-Sents-FULL   scibert_scivocab_uncased             MLPClassifier
# 57  PMC-Sents-FULL   scibert_scivocab_uncased    RandomForestClassifier
# 59  PMC-Sents-FULL   scibert_scivocab_uncased                       SVM
# 40  PMC-Sents-FULL   st_minilm_pmc_sents_full    DecisionTreeClassifier
# 41  PMC-Sents-FULL   st_minilm_pmc_sents_full  KNeighborsClassifierSqrt
# 43  PMC-Sents-FULL   st_minilm_pmc_sents_full             MLPClassifier
# 42  PMC-Sents-FULL   st_minilm_pmc_sents_full    RandomForestClassifier
# 44  PMC-Sents-FULL   st_minilm_pmc_sents_full                       SVM
# 45  PMC-Sents-FULL  st_scibert_pmc_sents_full    DecisionTreeClassifier
# 46  PMC-Sents-FULL  st_scibert_pmc_sents_full  KNeighborsClassifierSqrt
# 48  PMC-Sents-FULL  st_scibert_pmc_sents_full             MLPClassifier
# 47  PMC-Sents-FULL  st_scibert_pmc_sents_full    RandomForestClassifier
# 49  PMC-Sents-FULL  st_scibert_pmc_sents_full                       SVM
# 30      PubMed-RCT           all-MiniLM-L6-v2    DecisionTreeClassifier
# 31      PubMed-RCT           all-MiniLM-L6-v2  KNeighborsClassifierSqrt
# 33      PubMed-RCT           all-MiniLM-L6-v2             MLPClassifier
# 32      PubMed-RCT           all-MiniLM-L6-v2    RandomForestClassifier
# 34      PubMed-RCT           all-MiniLM-L6-v2                       SVM
# 35      PubMed-RCT   scibert_scivocab_uncased    DecisionTreeClassifier
# 36      PubMed-RCT   scibert_scivocab_uncased  KNeighborsClassifierSqrt
# 38      PubMed-RCT   scibert_scivocab_uncased             MLPClassifier
# 37      PubMed-RCT   scibert_scivocab_uncased    RandomForestClassifier
# 39      PubMed-RCT   scibert_scivocab_uncased                       SVM
# 20      PubMed-RCT       st_minilm_pubmed_rct    DecisionTreeClassifier
# 21      PubMed-RCT       st_minilm_pubmed_rct  KNeighborsClassifierSqrt
# 23      PubMed-RCT       st_minilm_pubmed_rct             MLPClassifier
# 22      PubMed-RCT       st_minilm_pubmed_rct    RandomForestClassifier
# 24      PubMed-RCT       st_minilm_pubmed_rct                       SVM
# 25      PubMed-RCT      st_scibert_pubmed_rct    DecisionTreeClassifier
# 26      PubMed-RCT      st_scibert_pubmed_rct  KNeighborsClassifierSqrt
# 28      PubMed-RCT      st_scibert_pubmed_rct             MLPClassifier
# 27      PubMed-RCT      st_scibert_pubmed_rct    RandomForestClassifier
# 29      PubMed-RCT      st_scibert_pubmed_rct                       SVM
#
#     f1_micro
# 10     41.59
# 11     57.89
# 13     57.89
# 12     55.37
# 14     61.23
# 15     50.19
# 16     71.68
# 18     68.57
# 17     69.61
# 19     76.20
# 0      61.45
# 1      74.65
# 3      70.79
# 2      75.02
# 4      61.90
# 5      68.57
# 6      77.61
# 8      70.72
# 7      78.50
# 9      75.76
# 50     46.21
# 51     62.72
# 53     64.01
# 52     60.32
# 54     69.55
# 55     52.94
# 56     66.76
# 58     66.69
# 57     66.49
# 59     72.01
# 40     60.01
# 41     71.42
# 43     71.39
# 42     71.54
# 44     71.37
# 45     71.31
# 46     75.76
# 48     73.25
# 47     75.89
# 49     76.27
# 30     44.54
# 31     61.61
# 33     74.24
# 32     62.01
# 34     77.99
# 35     64.54
# 36     82.60
# 38     81.73
# 37     81.74
# 39     86.75
# 20     79.61
# 21     85.19
# 23     82.99
# 22     85.65
# 24     83.00
# 25     82.28
# 26     87.05
# 28     86.29
# 27     87.19
# 29     87.12
